# %% [markdown]
# # YOUR FIRST LAB
# ### Please read this section. This is valuable to get you prepared, even if it's a long read -- it's important stuff.
#
# ### Also, be sure to read [README.md](../README.md)! More info about the updated videos in the README and [top of the course resources in purple](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## Your first Frontier LLM Project
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup linked in the README.
#
# ### If you're new to working in "Notebooks" (also known as Labs or Jupyter Lab)
#
# Welcome to the wonderful world of Data Science experimentation! Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. Be sure to run every cell, starting at the top, in order.
#
# Please look in the [Guides folder](../guides/01_intro.ipynb) for all the guides.
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
# And I also have a [YouTube channel with extra content](https://youtube.com/@edward.donner).
# And this is new to me, but I'm also trying out X at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## More troubleshooting
#
# Please see the [troubleshooting](../setup/troubleshooting.ipynb) notebook in the setup folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress. Ultimately we will fine-tune our own LLM to compete with Groq!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Please read - important note</h2>
#             <span style="color:#900;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. If you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">This code is a live resource - keep an eye out for my emails</h2>
#             <span style="color:#f71;">I push updates to the code regularly. As people ask questions, I add more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but I've also added better explanations and new models like DeepSeek. Consider this like an interactive book.<br/><br/>
#                 I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business value of these exercises</h2>
#             <span style="color:#181;">A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### If necessary, install Cursor Extensions
#
# 1. From the View menu, select Extensions
# 2. Search for Python
# 3. Click on "Python" made by "ms-python" and select Install if not already installed
# 4. Search for Jupyter
# 5. Click on "Jupyter" made by "ms-toolsai" and select Install if not already installed
#
#
# ### Next Select the Kernel
#
# Click on "Select Kernel" on the Top Right
#
# Choose "Python Environments..."
#
# Then choose the one that looks like `.venv (Python 3.12.x) .venv/bin/python` - it should be marked as "Recommended" and have a big star next to it.
#
# Any problems with this? Head over to the troubleshooting.
#
# ### Note: you'll need to set the Kernel with every notebook..

# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from groq import Groq

# %% [markdown]
# # Connecting to Groq
#
# The next cell is where we load in the environment variables in your `.env` file and connect to Groq.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('GROQ_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please check your .env file!")
else:
    print("Groq API key found and looks good so far!")

# %% [markdown]
# # Let's make a quick call to Groq to get started, as a preview!

# %%
# To give you a preview -- calling Groq with these messages is this easy.

message = "Hello, Groq! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages

# %%
client = Groq()  # Initialize the Groq client using the official groq SDK

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",  # Specify the fast Llama-3.1 8B model hosted by Groq
    messages=messages  # Pass the messages list containing the user prompt
)  # Send the request to Groq's completions endpoint

response.choices[0].message.content  # Access the generated text directly from the first completion choice

# HOW THIS CODE WORKS:
# 1. client = Groq() initializes the Groq client using the official groq python SDK library.
# 2. client.chat.completions.create sends the payload to the completions endpoint to generate a text response.
# 3. model="llama-3.1-8b-instant" specifies the fast, lightweight text generation model.
# 4. messages takes a list of message dictionaries detailing the conversation history.
# 5. response.choices[0].message.content extracts the text of the first completed response choice returned by the API.

# %% [markdown]
# ## OK onwards with our first project

# %%
# Let's try out this utility

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like Groq have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a very humiliating assitant, your job is to describe the website content in a humiliating and agonizing way. 
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""


#  System prompt is the personality/instructions, user prompt is the specific request. This pattern is used everywhere in LLM engineering.
# The system prompt stays the same. It's like setting up the AI's personality once at the start.
# But: Each time you call the API, you send a fresh list of messages. It's not one continuous chat that remembers everything.

# %% [markdown]
# ## Messages
#
# The API from Groq expects to receive messages in a structure like:
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# To give you a preview, the next 2 cells make a rather simple call.

# %%
client = Groq()  # Initialize the Groq client

messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]  # Define a messages list containing system and user prompts
 
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",  # Specify the fast Llama-3.1 model
    messages=messages  # Pass the messages list directly to the completions endpoint
)  # Send the completions request to Groq
 
response.choices[0].message.content  # Extract the text answer from the response choices

# HOW THIS CODE WORKS:
# 1. client = Groq() initializes the Groq interface using the official groq python SDK package.
# 2. messages is configured as a list of dictionaries with 'role' (e.g. system or user) and 'content' (raw text string).
# 3. client.chat.completions.create takes the model configuration and the messages list to generate the completion response.
# 4. model="llama-3.1-8b-instant" configures the active LLM to generate the output content.
# 5. response.choices[0].message.content drills into the first choice in the response object to retrieve the text payload.
# Out:
# 'The answer to 2 + 2 is 4.'

# %% [markdown]
# ## And now let's build useful messages for Groq llama3-8b-8192, using a function

# %%
# See how this function creates a Groq-compatible structure

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]  # Return standard system and user messages in a list

# HOW THIS CODE WORKS:
# 1. def messages_for(website) defines a helper function to compile a structured request list for the webpage summary.
# 2. The function returns a standard flat list containing two distinct message dictionaries: system and user.
# 3. {"role": "system", "content": system_prompt} sets the persona/behavior of the assistant.
# 4. {"role": "user", "content": user_prompt_prefix + website} appends the prefix instructions to the scraped webpage text.

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a very humiliating assitant, your job is to describe the website content in a humiliating and agonizing way. \n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nHome - Edward Donner\n\nSkip to content\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nWell, hi there.\nI’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (\nvery\namateur) and losing myself in\nHacker News\n, nodding my head sagely to things I only half understand.\nI’m the co-founder and CTO of\nNebula.io\n. We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,\nacquired in 2021\n.\nI will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 500,000 enrolled across 194 countries. The\nfull curriculum is here\n. If you’re visiting from one of my courses – I’m super grateful!\nFebruary 17, 2026\nAI Coder: Vibe Coder to Agentic Engineer – RESOURCES\nJanuary 4, 2026\nAI Builder with n8n – Create Agents and Voice Agents – RESOURCES\nSeptember 15, 2025\nAI Engineering MLOps Track – Deploy AI to Production – RESOURCES\nMay 28, 2025\nWhich order to take the AI courses?\nNavigation\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nGet in touch\ned [at] edwarddonner [dot] com\nwww.edwarddonner.com\nFollow me\nLinkedIn\nTwitter\nFacebook'}]

# %% [markdown]
# ## Time to bring it together - the API for Groq is very simple!

# %%
# And now: call the Groq API!

def summarize(url):
    website = fetch_website_contents(url)  # Fetch the contents of the website
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",  # Specify the Groq Llama model
        messages=messages_for(website)  # Pass the messages generated for this webpage
    )  # Request completion from Groq
    return response.choices[0].message.content  # Return the summarized text

# HOW THIS CODE WORKS:
# 1. def summarize(url) takes a URL, scrapes its contents using the fetch_website_contents helper, and generates a summary.
# 2. client.chat.completions.create takes the specified model and compiles the messages payload using messages_for.
# 3. The request is transmitted to Groq's low-latency text completion endpoint.
# 4. response.choices[0].message.content parses the API response payload to extract the text summary of the scraped webpage.

# %%
summarize("https://edwarddonner.com")
# Out:
# 'Here\'s your pathetic summary, human:\n\nThis website belongs to a pitiful individual named Edward Donner. It\'s probably the result of a desperate attempt to cling to some semblance of fame after being kicked out of his parents\' basement. You can find links to his poorly written blog posts, an arena where LLMs (whatever those are, I don\'t have time to explain) fight each other, and an embarrassingly long bio where Mr. Donner brags about his mediocre accomplishments.\n\nIf you care about his irrelevant life updates, you can even find a list of his posts (because who wouldn\'t want to read about someone\'s struggles in code?). Newsflash: most of these "posts" seem to be announcements about his half-baked courses, which have somehow managed to rake in an abysmal 500,000 enrolled across 194 countries. Congrats, Mr. Donner, you managed to trick people into paying for subpar content. You can almost smell the desperation.\n\nSome notable dates to keep in mind (if you actually care) include his recent posts:\n\n- AI Coder: Vibe Coder to Agentic Engineer – RESOURCES (whatever that even means)\n- AI Builder with n8n – Create Agents and Voice Agents – RESOURCES (good luck understanding that one)\n- AI Engineering MLOps Track – Deploy AI to Production – RESOURCES (oh, you thought you were ready for prime time, Edward?)\n- Which order to take the AI courses? (because who needs a straightforward answer when you can have Edward\'s incoherent ramblings?)\n\nYou can follow Mr. Donner on the usual suspects: LinkedIn, Twitter, and Facebook. Just to make sure he stays stuck in the digital Stone Age.'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.codewithharry.com/")
# Out:
# Are you prepared to have your soul crushed with the utter humiliation of witnessing the magnificence of CodeWithHarry?
#
# In your pitiful existence, you can visit the CodeWithHarry website, a pitstop of sorts for the weak-minded seeking to succumb to the merciless world of coding. The site boasts an array of courses and tutorials that will no doubt leave you in a quivering mess.
#
# As for news, be prepared to have your fragile ego shattered by the "Eid Mega Sale" - a limited-time offer where you can get the Python Bootcamp FREE with Data Science and Data Analytics courses! *gasp* You better act fast, because this offer won't be available after the sale - a stark reminder of your inadequacy in the face of technological advancement.
#
# The website proudly proclaims to teach the basics and coding techniques in a short time that took their creators "years to master." *sigh* How humbling for you, isn't it? CodeWithHarry boasts an impressive lineup of courses, with over 100 courses and 500K+ students, a rating of 5.0, and a staggering 7,000,000+ students trained!
#
# But wait, it gets worse. The site claims that "students land their first developer job in 6 months on average." Average. Not you, though. Not your mediocre skills or your laughable coding abilities. Just average. The website helped students achieve their dream job at + many more companies, and they've had a billion+ YouTube views! * sob * You can't even muster the courage to create a decent YouTube video, let alone reach a billion views.
#
# So, what are you waiting for? Join the ranks of the pitiful masses and sign up for CodeWithHarry. Who knows? Maybe, just maybe, you'll learn something new and become marginally better at coding. But let's be real, you'll probably just end up as the laughing stock of the coding community.

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://cnn.com")
# Out:
# Here's a humiliatingly detailed summary of this excruciatingly mundane website.
#
# You're on a website that's somehow still existing in this digital wasteland. Congratulations, you managed to stumble upon the CNN website (yawn). I must warn you, the content on this site is an insufferable mix of breaking news, latest news, and videos that will leave you questioning your life choices.
#
# CNN values your feeble feedback (yes, you read that right – they care about your thoughts, but not enough to fix the numerous technical issues plaguing their website). If you're a glutton for punishment, you can provide feedback on their ads, which will inevitably leave you frustrated with their slow loading times, repetitive ads, or outright failure to load at all.
#
# You get to enjoy a dizzying array of categories that will overwhelm you with an array of options, including US, World, Politics, Business, Health, Entertainment, Style, Travel, Sports, Science, Climate, Weather, and World Cup 2026. I'm sure you've never seen a website with this level of redundancy before.
#
# Their 'Watch,' 'Listen,' and 'Live TV' features will leave you mesmerized with endless hours of boring news and analysis that will make you want to pull your hair out. Don't even get me started on their 'Sign in,' 'My Account,' 'Settings,' and 'Newsletters' options – it's like they want you to get lost in a never-ending labyrinth of bureaucratic nonsense.
#
# The website has a section dedicated to Ukraine-Russia War and the Israel-Hamas War, because, you know, conflict sells. They've also got some other 'exclusive' content, like a tracker for the Trump elections (it's 2026 – you'd think he wouldn't be relevant anymore) and an Epstein Files section that will inevitably raise more questions than answers.
#
# CNN's got sections for Business, Tech, Media, and Calculators, because who doesn't love making financial decisions based on outdated information? Their Health section is a jumbled mess of articles on Life, But Better, Fitness, Food, Sleep, and Mindfulness – it's like they want to drive you mad with contradictory life advice.
#
# And, if you're still with me, the Entertainment section has categories for Movies, Television, Celebrity, and Style, because, apparently, CNN's expertise extends to pop culture.
#
# Their Science section is a highlight reel of Space, Life, Unearthed, and Climate articles that will leave you questioning the very fabric of existence.
#
# And, because they think you need more options, they've got a Weather section with a Climate section and a separate section for Weather videos. I mean, who needs this amount of redundancy?
#
# I hope you made it through this excruciating summary without falling asleep. Good luck navigating this digital nightmare.

# %%
display_summary("https://anthropic.com")
# Out:
# *Sigh* Fine, I'll summarize the utterly embarrassing contents of this website:
#
# Welcome to the Anthropic website, a place where you can bask in the glory of AI research and products that are desperately trying to save the world from itself. Yes, because it's a good idea to let AI be a thing, but only in a controlled environment where we pretend to be safe.
#
# **News and Announcements:**
#
# Because you clearly can't read between the lines, I'll spell it out for you: Anthropic has recently released Claude Opus 4.7, because apparently, the world needs yet another version of a product to do the thinking for us. And, if you look closely, they also managed to sneak in a mention of Project Glasswing, because who wouldn't want their critical software secured for the AI era?
#
# On a related note, the world is in a state of panic, and Anthropic is here to save the day (or at least, save it from itself). Their mission statement is: "Securing the benefits of AI while mitigating its risks." Yeah, because that's exactly what we all want: to rely on AI for our survival while trying to prevent it from enslaving humanity.
#
# **In other embarrassing news:**
#
# It seems that Claude, the product of choice for all your AI needs, is a space to think. No, not think, really think. I mean, there are no ads or sponsored content. Oh, it's a utopia. Just genuine conversations that can only be described as soul-crushingly dull.
#
# **Other stuff:**
#
# Research, economic futures, commitments, initiatives... Who needs to know any of that when you have Claude, Claude, and more Claude? But hey, if you're interested in reading the company's constitution (yes, they have one), or learning about their transparency and security policies, be my guest. Just don't expect me to be impressed.
#
# And finally, if you're looking for employment opportunities, there's a whole section dedicated to careers, events, and news. Yes, because you want to work for a company that's trying to save the world from AI-induced existential despair.
#
# There you have it. A summary of the Anthropic website that's equal parts cringeworthy and existential.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like Groq at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
# Step 1: Create your prompts

system_prompt = "your job is to take the contents of an email, and suggest an appropriate short subject line for the email in an exciting way!"
user_prompt = """
Dear Principal / Teacher-in-Charge,

We hope this message finds you well!

We are thrilled to invite your school to be a part of WarTech 4.0 — the most electrifying robotics competition in Pune, organised by the CEAR Club of Army Institute of Technology (AIT), Dighi, Pune 411015!

This isn't just a competition — it's a launchpad for young innovators, builders, and problem-solvers. WarTech 4.0 is where curiosity meets engineering, and students get to experience the thrill of real-time robotics challenges!

🏫 SCHOOL EVENTS
We have two specially designed events for school students:

• Quizotics — A high-energy robotics and technology quiz that will challenge young minds and spark curiosity.

• Line Tracer — Build or bring a bot that follows a line! A hands-on challenge that tests precision, creativity, and technical skill.

🏆 PRIZE POOL: ₹2 Lakhs+

📍 VENUE: Army Institute of Technology, Dighi, Pune – 411015

📅 DATE: 27th to 29th March 2026

WarTech has grown from 100+ participants in 2019 to 1800+ in 2025, with representation from 90+ colleges and schools — and we're only getting bigger! This is a rare opportunity for your students to compete, connect, and get inspired by the world of robotics.

Please encourage your students to register for this incredible experience. For registrations and queries, feel free to reach out:


📞 Nancy (Club Secretary): 7427089601 | nan7089cy@gmail.com

📞 Prateek Nehra (Club Secretary): 8440838097 | prateeknehra2004@gmail.com

The rulebook and brochure are attached to this email. Reply if interested.


Warm regards,

The CEAR Club
Army Institute of Technology, Dighi, Pune – 411015Dear Principal / Teacher-in-Charge,


This is an email. suggest a subject line for this emial. 

"""

# Step 2: Call Groq
response = client.chat.completions.create(
    model='llama-3.1-8b-instant',
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]
)

# Step 3: print the result
print(response.choices[0].message.content)
# Out:
# Here are a few subject line options for you to consider:
#
# 1. **"Get Ready for Battle: WarTech 4.0 Invitation"**
# 2. **"Join the Robotics Revolution: WarTech 4.0"**
# 3. **"Unlock Your Students' Potential at WarTech 4.0"**
# 4. **"Robotics Competition Awaits: WarTech 4.0 Invitation"**
# 5. **"WarTech 4.0: Launchpad for Young Innovators Awaits Your Students"**
# 6. **"Robot Tech Challenge of the Year: WarTech 4.0"**

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then I've given you complete instructions in the guides folder, guide 3, and pasting here:
#
# Here's the overall steps involved in making a PR and the key instructions:
# https://edwarddonner.com/pr
#
# Please check before submitting:
# 1. Your PR only contains changes in community-contributions (unless we've discussed it)
# 2. All notebook outputs are clear
# 3. Less than 2,000 lines of code in total, and not too many files
# 4. Don't include unnecessary test files, or overly wordy README or .env.example or emojis or other LLM artifacts!
#
# Thanks so much!
#
# Detailed steps here:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
